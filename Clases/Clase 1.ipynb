# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Now
# Out:
# DateObject[{2026, 2, 25, 10, 40, 25.255591}, Instant, Gregorian, -5.]

# %% [markdown]
# $$dr = \frac{\partial r}{\partial u_1} du_1 + \frac{\partial r}{\partial u_2} du_2 + \frac{\partial r}{\partial u_3} du_3 = \sum_{i=1}^{3} \frac{\partial r}{\partial u_i} du_i$$

# %% [markdown]
# * Coordenadas cartesianas [Figura]
# * Vector Posición
# * Vectores unitarios y notación
# * Ejemplo para entender contracción de índices (Notación de Einstein)
# * Símbolo delta de Kronecker $\delta_{ij}$

# %% [markdown]
# Serie Geométrica
#
# $$\sum_{n=0}^{\infty} a r^n \quad\quad |r|<1$$

# %%
1+1
# Out:
# 2

# %%
Sum[a * r^n, {n, 0, Infinity}, Assumptions -> Abs[r] < 1]
# Out:
#   a
# -----
# 1 - r

# %%
Sum[(x)^n, {n, 0, 5}] // TraditionalForm
# Out:
# FormBox[RowBox[{SuperscriptBox["x", "5"], "+", SuperscriptBox["x", "4"], "+",
#
#
# >        SuperscriptBox["x", "3"], "+", SuperscriptBox["x", "2"], "+", "x", "+", "1"}],
#
#
# >      TraditionalForm]

# %% [markdown]
# Ejemplo
#
# $$\sum_{n=0}^{\infty} (1/2)^n \delta_{2n} = (1/2)^2$$
#
# El símbolo actúa como seleccionador -> Ejemplo (Señales en furier) [audio]

# %%
Sum[(1/2)^n * KroneckerDelta[2,n], {n, 0, Infinity}]
# Out:
# 1
# -
# 4

# %% [markdown]
# **2. Coordenadas Cilíndricas**
#
# $(\rho, \varphi, z)$
#
# Mostrar transformación de coordenadas entre cartesianas y cilíndricas

# %% [markdown]
# **3. Coordenadas esféricas**
#
# $(r,\varphi, \theta)$
#
# * Escribir coordordenaas cartesianas en términos de coordenadas esféricas
# * Visualizar el dominio de cada coordenada

# %% [markdown]
# Ver texto de Alonso paras visualizar otros sistemas coordenados

# %% [markdown]
# Generalización de coordenadas -> Dibujo de planos que intersecan en un punto (la coordenada $P$) -> Visualización de vectores perpendiculares
